# %%
from datetime import datetime, timedelta
import numpy as np
import random
from infrastructure import *
from signaling import *
from system import *
from train import *
from dispatch import *
import networkx as nx
from sim import *
from rail_networkx import *
from itertools import combinations, permutations

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from rail_networkx import all_simple_paths, shortest_path

# %%
sim_init_time = datetime.strptime('2018-01-10 10:00:00', "%Y-%m-%d %H:%M:%S")
sim_term_time = datetime.strptime('2018-01-10 15:30:00', "%Y-%m-%d %H:%M:%S")
spd_container = [random.uniform(0.01, 0.02) for i in range(20)]
acc_container = [0.5*random.uniform(2.78e-05*0.85, 2.78e-05*1.15) for i in range(20)]
dcc_container = [0.2*random.uniform(2.78e-05*0.85, 2.78e-05*1.15) for i in range(20)]
headway = 300 + random.random() * 400
sys = System(sim_init_time, spd_container, acc_container, dcc_container,
             term_time=sim_term_time,
             dos_period=['2018-01-10 11:30:00', '2018-01-10 12:30:00'],  
             dos_pos=(15,20),
             headway=headway, 
             refresh_time=50)
dp = Dispatcher(sys)
# K165 = Train(sys, 
#              ((sys.signal_points[0],1),(sys.signal_points[1],0)),
#              ((sys.signal_points[10],1),(None,None)),
#              max_spd=random.choice(sys.spd_container),
#              max_acc=random.choice(sys.acc_container),
#              max_dcc=random.choice(sys.dcc_container),
#              length=1)
# T165 = Train(sys, 
#              ((None,None),(sys.signal_points[0],0)),
#              ((sys.signal_points[10],1),(None,None)),
#              max_spd=K165.max_spd*1.02,
#              max_acc=random.choice(sys.acc_container),
#              max_dcc=random.choice(sys.dcc_container),
#              length=1)
# K166 = Train(sys, 
#              ((sys.signal_points[10],0),(sys.signal_points[9],1)),
#              ((sys.signal_points[0],0),(None,None)),
#              max_spd=random.choice(sys.spd_container),
#              max_acc=random.choice(sys.acc_container),
#              max_dcc=random.choice(sys.dcc_container),
#              length=1)
# T166 = Train(sys, 
#              ((None,None),(sys.signal_points[10],1)),
#              ((sys.signal_points[0],0),(None,None)),
#              max_spd=K166.max_spd*1.02,
#              max_acc=random.choice(sys.acc_container),
#              max_dcc=random.choice(sys.dcc_container),
#              length=1)

# %%
def launch(downtrain=True):
    while sys.sys_time - sys.init_time <= sys.term_time - sys.init_time:
        _semaphore_to_return = False
        for t in sys.trains:
            t.request_routing()
            t.update_acc()
        if sys.sys_time+sys.refresh_time - sys.last_train_init_time >= sys.headway:
            if downtrain:
                if not sys.signal_points[0].curr_train_with_route.keys():
                    if all([t.curr_routing_path_segment != ((None,None),(sys.signal_points[0],0)) for t in sys.trains]):
                        if not sys.signal_points[0].track_by_port[1].train:
                            t = sys.generate_train( sys.signal_points[0],0,
                                                    sys.signal_points[10],1,
                                                    length=1)
            else:
                if not sys.signal_points[10].curr_train_with_route.keys():
                    if all([t.curr_routing_path_segment != ((None,None),(sys.signal_points[10],1)) for t in sys.trains]):
                        if not sys.signal_points[10].track_by_port[0].train:
                            t = sys.generate_train( sys.signal_points[10],1,
                                                    sys.signal_points[0],0,
                                                    length=1)
        sys.sys_time+=sys.refresh_time
launch(downtrain=False)
# Out:
# train idx: 0 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 0 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# train idx: 0 occupying:[((CtrlPnt10, 0), (AutoPnt 9, 1)), ((None, None), (CtrlPnt10, 1))] head MP:49.94 rear MP:50.94, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# train idx: 1 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 1 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 0) of CtrlPnt 8 is closed
# train idx: 0 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.94 rear MP:40.94, requested (1, 2) at 35.0
# 	route (1, 2) of CtrlPnt 7 is opened
# train idx: 1 occupying:[((CtrlPnt10, 0), (AutoPnt 9, 1))] head MP:47.46 rear MP:48.46, requested (1, 2) at 40.0
# 	route (1, 2) of CtrlPnt 8 is opened
# train idx: 2 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 2 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 2) of CtrlPnt 7 is closed
# 	route (1, 2) of CtrlPnt 8 is closed
# train idx: 1 occupying:[((CtrlPnt 8, 2), (AutoPnt12, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.99 rear MP:40.99, requested (3, 0) at 25.0
# 	route (3, 0) of CtrlPnt 5 is opened
# train idx: 0 occupying:[((CtrlPnt 7, 2), (CtrlPnt 6, 3))] head MP:30.34 rear MP:31.34, requested (3, 0) at 30.0
# 	route (3, 0) of CtrlPnt 6 is opened
# 	route (3, 0) of CtrlPnt 6 is closed
# train idx: 2 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1)), ((CtrlPnt10, 0), (AutoPnt 9, 1))] head MP:44.99 rear MP:45.99, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# train idx: 3 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 3 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (3, 0) of CtrlPnt 5 is closed
# train idx: 1 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((AutoPnt11, 0), (CtrlPnt 5, 3))] head MP:24.77 rear MP:25.77, requested (1, 0) at 20.0
# 	route (1, 0) of CtrlPnt 4 is opened
# train idx: 0 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:26.18 rear MP:27.18, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# train idx: 2 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.99 rear MP:40.99, requested (1, 0) at 35.0
# 	route (1, 0) of CtrlPnt 7 is opened
# 	route (1, 0) of CtrlPnt 4 is closed
# train idx: 1 occupying:[((CtrlPnt 4, 0), (CtrlPnt 3, 1)), ((CtrlPnt 5, 0), (CtrlPnt 4, 1))] head MP:19.79 rear MP:20.79, requested (1, 0) at 15.0
# 	route (1, 0) of CtrlPnt 3 is opened
# train idx: 4 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 4 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 0) of CtrlPnt 5 is closed
# train idx: 3 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:43.07 rear MP:44.07, requested (1, 2) at 40.0
# 	route (1, 2) of CtrlPnt 8 is opened
# train idx: 0 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:24.98 rear MP:25.98, requested (1, 2) at 20.0
# 	route (1, 2) of CtrlPnt 4 is opened
# 	route (1, 0) of CtrlPnt 7 is closed
# 	route (1, 2) of CtrlPnt 8 is closed
# 	route (1, 0) of CtrlPnt 3 is closed
# train idx: 1 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 0), (CtrlPnt 3, 1))] head MP:14.79 rear MP:15.79, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# 	route (1, 2) of CtrlPnt 4 is closed
# train idx: 0 occupying:[((CtrlPnt 4, 2), (CtrlPnt 3, 3)), ((CtrlPnt 5, 0), (CtrlPnt 4, 1))] head MP:19.91 rear MP:20.91, requested (3, 0) at 15.0
# 	route (3, 0) of CtrlPnt 3 is opened
# train idx: 5 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 5 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 1 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.79 rear MP:10.79, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# train idx: 2 occupying:[((CtrlPnt 7, 0), (CtrlPnt 6, 1))] head MP:30.02 rear MP:31.02, requested (1, 0) at 30.0
# 	route (1, 0) of CtrlPnt 6 is opened
# 	route (1, 0) of CtrlPnt 6 is closed
# train idx: 3 occupying:[((AutoPnt11, 0), (CtrlPnt 5, 3)), ((AutoPnt12, 0), (AutoPnt11, 1))] head MP:29.96 rear MP:30.96, requested (3, 0) at 25.0
# 	route (3, 0) of CtrlPnt 5 is opened
# train idx: 4 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:40.77 rear MP:41.77, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# train idx: 4 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.94 rear MP:40.94, requested (1, 2) at 35.0
# 	route (1, 2) of CtrlPnt 7 is opened
# 	route (3, 0) of CtrlPnt 3 is closed
# train idx: 0 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 2), (CtrlPnt 3, 3))] head MP:14.91 rear MP:15.91, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# train idx: 6 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 6 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 0) of CtrlPnt 0 is closed
# 	route (3, 0) of CtrlPnt 5 is closed
# train idx: 3 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((AutoPnt11, 0), (CtrlPnt 5, 3))] head MP:24.96 rear MP:25.96, requested (1, 0) at 20.0
# 	route (1, 0) of CtrlPnt 4 is opened
# 	route (1, 2) of CtrlPnt 7 is closed
# train idx: 2 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:25.13 rear MP:26.13, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 0 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.91 rear MP:10.91, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# 	route (1, 0) of CtrlPnt 4 is closed
# train idx: 3 occupying:[((CtrlPnt 4, 0), (CtrlPnt 3, 1)), ((CtrlPnt 5, 0), (CtrlPnt 4, 1))] head MP:19.96 rear MP:20.96, requested (1, 0) at 15.0
# 	route (1, 0) of CtrlPnt 3 is opened
# 	route (1, 0) of CtrlPnt 5 is closed
# train idx: 5 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:40.03 rear MP:41.03, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# 	route (1, 0) of CtrlPnt 0 is closed
# train idx: 2 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:24.99 rear MP:25.99, requested (1, 2) at 20.0
# 	route (1, 2) of CtrlPnt 4 is opened
# train idx: 5 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.97 rear MP:40.97, requested (1, 0) at 35.0
# 	route (1, 0) of CtrlPnt 7 is opened
# 	route (1, 0) of CtrlPnt 3 is closed
# train idx: 7 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 7 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# train idx: 3 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 0), (CtrlPnt 3, 1))] head MP:14.96 rear MP:15.96, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# 	route (1, 0) of CtrlPnt 7 is closed
# 	route (1, 2) of CtrlPnt 4 is closed
# train idx: 5 occupying:[((CtrlPnt 7, 0), (CtrlPnt 6, 1)), ((CtrlPnt 8, 0), (CtrlPnt 7, 1))] head MP:34.91 rear MP:35.91, requested (1, 0) at 30.0
# 	route (1, 0) of CtrlPnt 6 is opened
# train idx: 2 occupying:[((CtrlPnt 4, 2), (CtrlPnt 3, 3)), ((CtrlPnt 5, 0), (CtrlPnt 4, 1))] head MP:19.76 rear MP:20.76, requested (3, 0) at 15.0
# 	route (3, 0) of CtrlPnt 3 is opened
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 3 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.96 rear MP:10.96, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# 	route (1, 0) of CtrlPnt 6 is closed
# 	route (3, 0) of CtrlPnt 3 is closed
# train idx: 5 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1)), ((CtrlPnt 7, 0), (CtrlPnt 6, 1))] head MP:29.91 rear MP:30.91, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# train idx: 2 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 2), (CtrlPnt 3, 3))] head MP:14.76 rear MP:15.76, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# 	route (1, 0) of CtrlPnt 0 is closed
# 	route (1, 0) of CtrlPnt 5 is closed
# train idx: 6 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:40.00 rear MP:41.00, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 4 occupying:[((CtrlPnt 7, 2), (CtrlPnt 6, 3))] head MP:30.02 rear MP:31.02, requested (3, 0) at 30.0
# 	route (3, 0) of CtrlPnt 6 is opened
# train idx: 5 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:24.91 rear MP:25.91, requested (1, 2) at 20.0
# 	route (1, 2) of CtrlPnt 4 is opened
# train idx: 6 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.94 rear MP:40.94, requested (1, 0) at 35.0
# 	route (1, 0) of CtrlPnt 7 is opened
# train idx: 2 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.76 rear MP:10.76, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# 	route (3, 0) of CtrlPnt 6 is closed
# train idx: 4 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1)), ((CtrlPnt 7, 2), (CtrlPnt 6, 3))] head MP:29.96 rear MP:30.96, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# train idx: 8 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 8 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 2) of CtrlPnt 4 is closed
# 	route (1, 0) of CtrlPnt 0 is closed
# train idx: 5 occupying:[((CtrlPnt 4, 2), (CtrlPnt 3, 3)), ((CtrlPnt 5, 0), (CtrlPnt 4, 1))] head MP:19.91 rear MP:20.91, requested (3, 0) at 15.0
# 	route (3, 0) of CtrlPnt 3 is opened
# 	route (1, 0) of CtrlPnt 7 is closed
# 	route (1, 0) of CtrlPnt 5 is closed
# train idx: 7 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:40.68 rear MP:41.68, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# train idx: 4 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:24.95 rear MP:25.95, requested (1, 0) at 20.0
# 	route (1, 0) of CtrlPnt 4 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# train idx: 7 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.85 rear MP:40.85, requested (1, 2) at 35.0
# 	route (1, 2) of CtrlPnt 7 is opened
# 	route (3, 0) of CtrlPnt 3 is closed
# train idx: 5 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 2), (CtrlPnt 3, 3))] head MP:14.91 rear MP:15.91, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# train idx: 9 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx: 9 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 0) of CtrlPnt 4 is closed
# train idx: 4 occupying:[((CtrlPnt 4, 0), (CtrlPnt 3, 1)), ((CtrlPnt 5, 0), (CtrlPnt 4, 1))] head MP:19.95 rear MP:20.95, requested (1, 0) at 15.0
# 	route (1, 0) of CtrlPnt 3 is opened
# 	route (1, 2) of CtrlPnt 7 is closed
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 5 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.91 rear MP:10.91, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# 	route (1, 0) of CtrlPnt 3 is closed
# train idx: 4 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 0), (CtrlPnt 3, 1))] head MP:14.95 rear MP:15.95, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# train idx: 6 occupying:[((CtrlPnt 7, 0), (CtrlPnt 6, 1))] head MP:30.03 rear MP:31.03, requested (1, 0) at 30.0
# 	route (1, 0) of CtrlPnt 6 is opened
# 	route (1, 0) of CtrlPnt 6 is closed
# train idx: 6 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1)), ((CtrlPnt 7, 0), (CtrlPnt 6, 1))] head MP:29.97 rear MP:30.97, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# 	route (1, 0) of CtrlPnt 0 is closed
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 4 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.95 rear MP:10.95, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# 	route (1, 0) of CtrlPnt 5 is closed
# train idx: 8 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:40.04 rear MP:41.04, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# train idx: 6 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:24.91 rear MP:25.91, requested (1, 2) at 20.0
# 	route (1, 2) of CtrlPnt 4 is opened
# train idx: 8 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.99 rear MP:40.99, requested (1, 0) at 35.0
# 	route (1, 0) of CtrlPnt 7 is opened
# 	route (1, 0) of CtrlPnt 0 is closed
# train idx:10 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx:10 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 2) of CtrlPnt 4 is closed
# 	route (1, 0) of CtrlPnt 7 is closed
# train idx: 8 occupying:[((CtrlPnt 7, 0), (CtrlPnt 6, 1)), ((CtrlPnt 8, 0), (CtrlPnt 7, 1))] head MP:34.88 rear MP:35.88, requested (1, 0) at 30.0
# 	route (1, 0) of CtrlPnt 6 is opened
# train idx: 6 occupying:[((CtrlPnt 4, 2), (CtrlPnt 3, 3))] head MP:18.80 rear MP:19.80, requested (3, 0) at 15.0
# 	route (3, 0) of CtrlPnt 3 is opened
# 	route (3, 0) of CtrlPnt 3 is closed
# train idx: 6 occupying:[((CtrlPnt 3, 0), (CtrlPnt 2, 1)), ((CtrlPnt 4, 2), (CtrlPnt 3, 3))] head MP:14.91 rear MP:15.91, requested (1, 0) at 10.0
# 	route (1, 0) of CtrlPnt 2 is opened
# 	route (1, 0) of CtrlPnt 6 is closed
# train idx: 8 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1)), ((CtrlPnt 7, 0), (CtrlPnt 6, 1))] head MP:29.88 rear MP:30.88, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# 	route (1, 0) of CtrlPnt 2 is closed
# train idx: 6 occupying:[((CtrlPnt 2, 0), (AutoPnt 1, 1)), ((CtrlPnt 3, 0), (CtrlPnt 2, 1))] head MP: 9.91 rear MP:10.91, requested (1, 0) at 0.0
# 	route (1, 0) of CtrlPnt 0 is opened
# 	route (1, 0) of CtrlPnt 5 is closed
# train idx: 9 occupying:[((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:40.03 rear MP:41.03, requested (1, 0) at 40.0
# 	route (1, 0) of CtrlPnt 8 is opened
# 	route (1, 0) of CtrlPnt 8 is closed
# train idx: 7 occupying:[((CtrlPnt 7, 2), (CtrlPnt 6, 3))] head MP:30.03 rear MP:31.03, requested (3, 0) at 30.0
# 	route (3, 0) of CtrlPnt 6 is opened
# train idx: 8 occupying:[((CtrlPnt 5, 0), (CtrlPnt 4, 1)), ((CtrlPnt 6, 0), (CtrlPnt 5, 1))] head MP:24.88 rear MP:25.88, requested (1, 0) at 20.0
# 	route (1, 0) of CtrlPnt 4 is opened
# train idx: 9 occupying:[((CtrlPnt 8, 0), (CtrlPnt 7, 1)), ((AutoPnt 9, 0), (CtrlPnt 8, 1))] head MP:39.97 rear MP:40.97, requested (1, 0) at 35.0
# 	route (1, 0) of CtrlPnt 7 is opened
# 	route (3, 0) of CtrlPnt 6 is closed
# train idx: 7 occupying:[((CtrlPnt 6, 0), (CtrlPnt 5, 1)), ((CtrlPnt 7, 2), (CtrlPnt 6, 3))] head MP:29.98 rear MP:30.98, requested (1, 0) at 25.0
# 	route (1, 0) of CtrlPnt 5 is opened
# train idx:11 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00, requested (1, 0) at 50.0
# 	route (1, 0) of CtrlPnt10 is opened
# train train idx:11 occupying:[((None, None), (CtrlPnt10, 1))] head MP:50.00 rear MP:51.00 initiated, entering into Track <MP: 45.0~50.0 > <AutoPnt 9 port: 1~CtrlPnt10 port: 0> key: 0
# 	route (1, 0) of CtrlPnt10 is closed
# 	route (1, 0) of CtrlPnt 0 is closed

# %%
string_diagram(sys)
# Out:
# No handles with labels found to put in legend.

# %%
speed_curve(sys,sys.trains[3])
# Out:
# No handles with labels found to put in legend.

# %%
K165.curr_home_sig.route

# %%
dp.get_route(sys.signal_points[8], 0, sys.signal_points[9],1,mainline=False)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-47-5d861cf0e4ad> in <module>
# ----> 1 dp.get_route(sys.signal_points[8], 0, sys.signal_points[9],1,mainline=False)
#
# ~/Documents/GitHub/Rutgers_Railway_security_research/OOD_Train/dispatch.py in get_route(self, src, srcport, tgt, tgtport, path, mainline)
#      50                     if mainline==True else \
#      51                     next(all_simple_paths(self.system.G_skeleton,
# ---> 52                                             source=src, target=tgt))
#      53         port_by_bblk = lambda bblk, cp: [p for p in cp.ports
#      54             if cp.bigblock_by_port.get(p) == bblk][0]
#
# StopIteration:

# %%
string_diagram(sys)
# Out:
# No handles with labels found to put in legend.

# %%
path = list(all_simple_paths(sys.G_origin, sys.signal_points[8], sys.signal_points[8]))[0]
for (i,j) in zip(path[0:],path[1:]):
    print(i,j)

# %%
dp.get_all_routes(sys.signal_points[8], 1, sys.signal_points[11], 0)
# Out:
# [[((CtrlPnt10, 0), (CtrlPnt 8, 1)), ((CtrlPnt 8, 0), (CtrlPnt 7, 1))]]

# %%
shortest_path(sys.G_origin, sys.signal_points[8], sys.signal_points[8])
# Out:
# [CtrlPnt 8]

# %%
dp.get_route(sys.signal_points[8], 1, sys.signal_points[11], 0)
# Out:
# [((CtrlPnt10, 0), (CtrlPnt 8, 1)), ((CtrlPnt 8, 0), (CtrlPnt 7, 1))]

# %%
for i in sys.bigblocks:
    if True:
        sys.bigblocks.remove(i)

# %%
sys.bigblocks
# Out:
# []
