# %%
import os
import sys
sys.path.append('D:\\Users\\Hegxiten\\workspace\\Rutgers_Railway_security_research\\OOD_Train')

from datetime import datetime, timedelta
import numpy as np
import random
from infrastructure import Track, Block, BigBlock
from signaling import AutoSignal, HomeSignal, AutoPoint, ControlPoint
from system import System
from train import Train
import networkx as nx

# %%
sim_init_time = datetime.strptime('2018-01-10 10:00:00', "%Y-%m-%d %H:%M:%S")
sim_term_time = datetime.strptime('2018-01-10 15:30:00', "%Y-%m-%d %H:%M:%S")
sp_container = [random.uniform(0.01, 0.02) for i in range(20)]
acc_container = [random.uniform(2.78e-05*0.85, 2.78e-05*1.15) for i in range(20)]
dcc_container = [random.uniform(2.78e-05*0.85, 2.78e-05*1.15) for i in range(20)]
headway = 200 * random.random() + 400
sys = System(sim_init_time, sp_container, acc_container, dcc_container,
             dos_period=['2018-01-10 11:30:00', '2018-01-10 12:30:00'],  
             headway=headway, 
             tracks=[1,1,1,4,1,1,3,1,1,1], 
             dos_pos=-1)
k166 = Train(idx=sys.train_num, 
                  rank=sys.train_num, 
                  system=sys, 
                  init_time=sys.sys_time, 
                  init_segment=((None, None),(sys.signal_points[0],0)),
                  max_sp=sys.sp_container[sys.train_num % len(sys.sp_container)], 
                  max_acc=sys.acc_container[sys.train_num % len(sys.acc_container)], 
                  max_dcc=sys.dcc_container[sys.train_num % len(sys.dcc_container)])

# %%
for t in sys.tracks:
    print(t.train)

for b in sys.curr_routing_paths:
    print(len(b))
    for i in b:
        print('\t',i)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
for n in range(3600):
#     print('k146: curr_MP: {}, \tcurr_spd: {}, \ttgt_spd: {},\tacc: {}'.format("%.2f" % round(k146.curr_MP,2), \
#                                                                    "%.2f" % round(k146.curr_speed*3600,2), \
#                                                                    "%.2f" % round(k146.curr_target_spd_abs*3600,2), \
#                                                                    "%.10f" % round(k146.curr_acc,10)))
    print('k166: curr_MP: {}, \tcurr_spd: {}, \ttgt_spd: {},\tbrk_dis: {}, \tacc: {},'.format(\
                                                                    "%.2f" % round(k166.curr_MP,2), \
                                                                   "%.2f" % round(k166.curr_speed*3600,2), \
                                                                   "%.2f" % round(k166.curr_target_spd_abs*3600,2), \
                                                                   "%.2f" % round(k166.curr_brake_distance_abs,2), \
                                                                   "%.10f" % round(k166.curr_acc,10)))
    k166.update_acc()
    sys.sys_time+=1
# Out:
# k166: curr_MP: 0.00, 	curr_spd: 0.00, 	tgt_spd: 65.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# train train index 0, current segment/direction ((None, None), (ControlPoint0, 0)) moved into track Track MP: 0.0 to MP: 5.0 idx: 0
# route (0, 1) of ControlPoint0 is closed
# k166: curr_MP: 0.00, 	curr_spd: 0.11, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.22, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.33, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.44, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.55, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.66, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.77, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.88, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 0.98, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.09, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.20, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.31, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.42, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.53, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.64, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.75, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.86, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.00, 	curr_spd: 1.97, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.08, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.19, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.30, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.41, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.52, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.63, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.74, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.84, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 2.95, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 3.06, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 3.17, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 3.28, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.01, 	curr_spd: 3.39, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 3.50, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 3.61, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 3.72, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 3.83, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 3.94, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 4.05, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 4.16, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 4.27, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.02, 	curr_spd: 4.38, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 4.49, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 4.60, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 4.70, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 4.81, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 4.92, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 5.03, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.03, 	curr_spd: 5.14, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.25, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.36, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.47, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.58, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.69, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.80, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.04, 	curr_spd: 5.91, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.05, 	curr_spd: 6.02, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.05, 	curr_spd: 6.13, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.05, 	curr_spd: 6.24, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.05, 	curr_spd: 6.35, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.05, 	curr_spd: 6.46, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.05, 	curr_spd: 6.56, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.06, 	curr_spd: 6.67, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.06, 	curr_spd: 6.78, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.06, 	curr_spd: 6.89, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.06, 	curr_spd: 7.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.06, 	curr_spd: 7.11, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.07, 	curr_spd: 7.22, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.07, 	curr_spd: 7.33, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.07, 	curr_spd: 7.44, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.07, 	curr_spd: 7.55, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.07, 	curr_spd: 7.66, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.08, 	curr_spd: 7.77, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.08, 	curr_spd: 7.88, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.08, 	curr_spd: 7.99, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.08, 	curr_spd: 8.10, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.09, 	curr_spd: 8.21, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.09, 	curr_spd: 8.32, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.09, 	curr_spd: 8.42, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.09, 	curr_spd: 8.53, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.09, 	curr_spd: 8.64, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.10, 	curr_spd: 8.75, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.10, 	curr_spd: 8.86, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.10, 	curr_spd: 8.97, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.10, 	curr_spd: 9.08, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.11, 	curr_spd: 9.19, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.11, 	curr_spd: 9.30, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.11, 	curr_spd: 9.41, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.12, 	curr_spd: 9.52, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.12, 	curr_spd: 9.63, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.12, 	curr_spd: 9.74, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.12, 	curr_spd: 9.85, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.13, 	curr_spd: 9.96, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.13, 	curr_spd: 10.07, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.13, 	curr_spd: 10.18, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.13, 	curr_spd: 10.28, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.14, 	curr_spd: 10.39, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.14, 	curr_spd: 10.50, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.14, 	curr_spd: 10.61, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.15, 	curr_spd: 10.72, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.15, 	curr_spd: 10.83, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.15, 	curr_spd: 10.94, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.16, 	curr_spd: 11.05, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.16, 	curr_spd: 11.16, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.16, 	curr_spd: 11.27, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.16, 	curr_spd: 11.38, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.17, 	curr_spd: 11.49, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.17, 	curr_spd: 11.60, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.17, 	curr_spd: 11.71, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.18, 	curr_spd: 11.82, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.18, 	curr_spd: 11.93, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.18, 	curr_spd: 12.04, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.19, 	curr_spd: 12.14, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.19, 	curr_spd: 12.25, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.19, 	curr_spd: 12.36, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.20, 	curr_spd: 12.47, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.20, 	curr_spd: 12.58, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.20, 	curr_spd: 12.69, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.21, 	curr_spd: 12.80, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.21, 	curr_spd: 12.91, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.22, 	curr_spd: 13.02, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.22, 	curr_spd: 13.13, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.22, 	curr_spd: 13.24, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.23, 	curr_spd: 13.35, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.23, 	curr_spd: 13.46, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.23, 	curr_spd: 13.57, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.24, 	curr_spd: 13.68, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.24, 	curr_spd: 13.79, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.25, 	curr_spd: 13.90, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.25, 	curr_spd: 14.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.25, 	curr_spd: 14.11, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.26, 	curr_spd: 14.22, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.26, 	curr_spd: 14.33, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.26, 	curr_spd: 14.44, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.27, 	curr_spd: 14.55, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.27, 	curr_spd: 14.66, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.28, 	curr_spd: 14.77, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.28, 	curr_spd: 14.88, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.29, 	curr_spd: 14.99, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.29, 	curr_spd: 15.10, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.29, 	curr_spd: 15.21, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.30, 	curr_spd: 15.32, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.30, 	curr_spd: 15.43, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.31, 	curr_spd: 15.54, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.31, 	curr_spd: 15.65, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.32, 	curr_spd: 15.76, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.32, 	curr_spd: 15.86, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.32, 	curr_spd: 15.97, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.33, 	curr_spd: 16.08, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.33, 	curr_spd: 16.19, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.34, 	curr_spd: 16.30, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.34, 	curr_spd: 16.41, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.35, 	curr_spd: 16.52, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.35, 	curr_spd: 16.63, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.36, 	curr_spd: 16.74, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.36, 	curr_spd: 16.85, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.37, 	curr_spd: 16.96, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.37, 	curr_spd: 17.07, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.37, 	curr_spd: 17.18, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.38, 	curr_spd: 17.29, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.38, 	curr_spd: 17.40, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.39, 	curr_spd: 17.51, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.39, 	curr_spd: 17.62, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.40, 	curr_spd: 17.72, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.40, 	curr_spd: 17.83, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.41, 	curr_spd: 17.94, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.41, 	curr_spd: 18.05, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.42, 	curr_spd: 18.16, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.42, 	curr_spd: 18.27, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.43, 	curr_spd: 18.38, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.43, 	curr_spd: 18.49, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.44, 	curr_spd: 18.60, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.44, 	curr_spd: 18.71, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.45, 	curr_spd: 18.82, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.45, 	curr_spd: 18.93, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.46, 	curr_spd: 19.04, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.47, 	curr_spd: 19.15, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.47, 	curr_spd: 19.26, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.48, 	curr_spd: 19.37, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.48, 	curr_spd: 19.48, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.49, 	curr_spd: 19.58, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.49, 	curr_spd: 19.69, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.50, 	curr_spd: 19.80, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.50, 	curr_spd: 19.91, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.51, 	curr_spd: 20.02, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.51, 	curr_spd: 20.13, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.52, 	curr_spd: 20.24, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.53, 	curr_spd: 20.35, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.53, 	curr_spd: 20.46, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.54, 	curr_spd: 20.57, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.54, 	curr_spd: 20.68, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.55, 	curr_spd: 20.79, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.55, 	curr_spd: 20.90, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.56, 	curr_spd: 21.01, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.57, 	curr_spd: 21.12, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.57, 	curr_spd: 21.23, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.58, 	curr_spd: 21.34, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.58, 	curr_spd: 21.44, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.59, 	curr_spd: 21.55, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.60, 	curr_spd: 21.66, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.60, 	curr_spd: 21.77, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.61, 	curr_spd: 21.88, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.61, 	curr_spd: 21.99, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.62, 	curr_spd: 22.10, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.63, 	curr_spd: 22.21, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.63, 	curr_spd: 22.32, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.64, 	curr_spd: 22.43, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.64, 	curr_spd: 22.54, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.65, 	curr_spd: 22.65, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.66, 	curr_spd: 22.76, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.66, 	curr_spd: 22.87, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.67, 	curr_spd: 22.98, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.68, 	curr_spd: 23.09, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.68, 	curr_spd: 23.20, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.69, 	curr_spd: 23.31, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.70, 	curr_spd: 23.41, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.70, 	curr_spd: 23.52, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.71, 	curr_spd: 23.63, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.72, 	curr_spd: 23.74, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.72, 	curr_spd: 23.85, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.73, 	curr_spd: 23.96, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.74, 	curr_spd: 24.07, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.74, 	curr_spd: 24.18, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.75, 	curr_spd: 24.29, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.76, 	curr_spd: 24.40, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.76, 	curr_spd: 24.51, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.77, 	curr_spd: 24.62, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.78, 	curr_spd: 24.73, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.78, 	curr_spd: 24.84, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.79, 	curr_spd: 24.95, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.80, 	curr_spd: 25.06, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.80, 	curr_spd: 25.17, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.81, 	curr_spd: 25.27, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.82, 	curr_spd: 25.38, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.82, 	curr_spd: 25.49, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.83, 	curr_spd: 25.60, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.84, 	curr_spd: 25.71, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.85, 	curr_spd: 25.82, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.85, 	curr_spd: 25.93, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.86, 	curr_spd: 26.04, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.87, 	curr_spd: 26.15, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.88, 	curr_spd: 26.26, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.88, 	curr_spd: 26.37, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.89, 	curr_spd: 26.48, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.90, 	curr_spd: 26.59, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.90, 	curr_spd: 26.70, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.91, 	curr_spd: 26.81, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.92, 	curr_spd: 26.92, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.93, 	curr_spd: 27.03, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.93, 	curr_spd: 27.13, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.94, 	curr_spd: 27.24, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.95, 	curr_spd: 27.35, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.96, 	curr_spd: 27.46, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.97, 	curr_spd: 27.57, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.97, 	curr_spd: 27.68, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.98, 	curr_spd: 27.79, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 0.99, 	curr_spd: 27.90, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.00, 	curr_spd: 28.01, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.00, 	curr_spd: 28.12, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.01, 	curr_spd: 28.23, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.02, 	curr_spd: 28.34, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.03, 	curr_spd: 28.45, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.04, 	curr_spd: 28.56, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.04, 	curr_spd: 28.67, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.05, 	curr_spd: 28.78, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.06, 	curr_spd: 28.89, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.07, 	curr_spd: 28.99, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.08, 	curr_spd: 29.10, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.08, 	curr_spd: 29.21, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.09, 	curr_spd: 29.32, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.10, 	curr_spd: 29.43, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.11, 	curr_spd: 29.54, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.12, 	curr_spd: 29.65, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.12, 	curr_spd: 29.76, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.13, 	curr_spd: 29.87, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.14, 	curr_spd: 29.98, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.15, 	curr_spd: 30.09, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.16, 	curr_spd: 30.20, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.17, 	curr_spd: 30.31, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.17, 	curr_spd: 30.42, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.18, 	curr_spd: 30.53, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.19, 	curr_spd: 30.64, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.20, 	curr_spd: 30.75, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.21, 	curr_spd: 30.85, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.22, 	curr_spd: 30.96, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.23, 	curr_spd: 31.07, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.23, 	curr_spd: 31.18, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.24, 	curr_spd: 31.29, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.25, 	curr_spd: 31.40, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.26, 	curr_spd: 31.51, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.27, 	curr_spd: 31.62, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.28, 	curr_spd: 31.73, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.29, 	curr_spd: 31.84, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.30, 	curr_spd: 31.95, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.30, 	curr_spd: 32.06, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.31, 	curr_spd: 32.17, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.32, 	curr_spd: 32.28, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.33, 	curr_spd: 32.39, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.34, 	curr_spd: 32.50, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.35, 	curr_spd: 32.61, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.36, 	curr_spd: 32.71, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.37, 	curr_spd: 32.82, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.38, 	curr_spd: 32.93, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.39, 	curr_spd: 33.04, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.40, 	curr_spd: 33.15, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.40, 	curr_spd: 33.26, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.41, 	curr_spd: 33.37, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.42, 	curr_spd: 33.48, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.43, 	curr_spd: 33.59, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.44, 	curr_spd: 33.70, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.45, 	curr_spd: 33.81, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.46, 	curr_spd: 33.92, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.47, 	curr_spd: 34.03, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.48, 	curr_spd: 34.14, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.49, 	curr_spd: 34.25, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.50, 	curr_spd: 34.36, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.51, 	curr_spd: 34.47, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.52, 	curr_spd: 34.57, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.53, 	curr_spd: 34.68, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.54, 	curr_spd: 34.79, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.55, 	curr_spd: 34.90, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.56, 	curr_spd: 35.01, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.57, 	curr_spd: 35.12, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.58, 	curr_spd: 35.23, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.59, 	curr_spd: 35.34, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.60, 	curr_spd: 35.45, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.61, 	curr_spd: 35.56, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.62, 	curr_spd: 35.67, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.62, 	curr_spd: 35.78, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.63, 	curr_spd: 35.89, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.64, 	curr_spd: 36.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.65, 	curr_spd: 36.11, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.66, 	curr_spd: 36.22, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.67, 	curr_spd: 36.33, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.69, 	curr_spd: 36.43, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.70, 	curr_spd: 36.54, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.71, 	curr_spd: 36.65, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.72, 	curr_spd: 36.76, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.73, 	curr_spd: 36.87, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.74, 	curr_spd: 36.98, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.75, 	curr_spd: 37.09, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.76, 	curr_spd: 37.20, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.77, 	curr_spd: 37.31, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.78, 	curr_spd: 37.42, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.79, 	curr_spd: 37.53, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.80, 	curr_spd: 37.64, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.81, 	curr_spd: 37.75, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.82, 	curr_spd: 37.86, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.83, 	curr_spd: 37.97, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.84, 	curr_spd: 38.08, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.85, 	curr_spd: 38.19, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.86, 	curr_spd: 38.29, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.87, 	curr_spd: 38.40, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.88, 	curr_spd: 38.51, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.89, 	curr_spd: 38.62, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.90, 	curr_spd: 38.73, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.92, 	curr_spd: 38.84, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.93, 	curr_spd: 38.95, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.94, 	curr_spd: 39.06, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.95, 	curr_spd: 39.17, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.96, 	curr_spd: 39.28, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.97, 	curr_spd: 39.39, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.98, 	curr_spd: 39.50, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 1.99, 	curr_spd: 39.61, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 2.00, 	curr_spd: 39.72, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 2.01, 	curr_spd: 39.83, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 2.02, 	curr_spd: 39.94, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000303926,
# k166: curr_MP: 2.04, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.05, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.06, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.07, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.08, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.09, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.10, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.11, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.12, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.14, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.15, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.16, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.17, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.18, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.19, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.20, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.21, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.22, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.24, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.25, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.26, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.27, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.28, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.29, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.30, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.31, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.32, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.34, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.35, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.36, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.37, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.38, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.39, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.40, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.41, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.42, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.44, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.45, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.46, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.47, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.48, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.49, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.50, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.51, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.52, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.54, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.55, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.56, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.57, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.58, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.59, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.60, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.61, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.62, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.64, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.65, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.66, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.67, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.68, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.69, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.70, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.71, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.72, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.74, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.75, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.76, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.77, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.78, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.79, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.80, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.81, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.82, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.84, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.85, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.86, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.87, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.88, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.89, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.90, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.91, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.92, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.94, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.95, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.96, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.97, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.98, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 2.99, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.00, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.01, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.02, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.04, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.05, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.06, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.07, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.08, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.09, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.10, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.11, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.12, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.14, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.15, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.16, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.17, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.18, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.19, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.20, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.21, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.22, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.24, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.25, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.26, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.27, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.28, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.29, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.30, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.31, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.32, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.34, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.35, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.36, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.37, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.38, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.39, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.40, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.41, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.42, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.44, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.45, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.46, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.47, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.48, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.49, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.50, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.51, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.52, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.54, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.55, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.56, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.57, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.58, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.59, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.60, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.61, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.62, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.64, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.65, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.66, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.67, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.68, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.69, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.70, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.71, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.72, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.74, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.75, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.76, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.77, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.78, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.79, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 3.80, 	curr_spd: 40.00, 	tgt_spd: 40.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# ...
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,
# k166: curr_MP: 10.50, 	curr_spd: 0.00, 	tgt_spd: 0.00,	brk_dis: 0.00, 	acc: 0.0000000000,

# %%
sys.signal_points[0].open_route((0,1))
# [n.close_route() for n in sys.control_points]
for b in sys.bigblocks:
    print(b, b.routing)
# Out:
# route (0, 1) of ControlPoint0 is opened
# BigBlock MP: 0.0 to MP: 15.0 idx: 0 ((ControlPoint0, 1), (ControlPoint3, 0))
# BigBlock MP: 15.0 to MP: 20.0 idx: 0 None
# BigBlock MP: 15.0 to MP: 20.0 idx: 1 None
# BigBlock MP: 20.0 to MP: 30.0 idx: 0 None
# BigBlock MP: 30.0 to MP: 35.0 idx: 0 None
# BigBlock MP: 30.0 to MP: 35.0 idx: 1 None
# BigBlock MP: 35.0 to MP: 50.0 idx: 0 None

# %%
for i in range(len(sys.signal_points)):
    print(i, sys.signal_points[i].signal_by_port[1].aspect)
# Out:
# 0 Aspect: r, 	 route None, target speed 0.0 mph
# 1 Aspect: y, 	 route (1, 0), target speed 20.0 mph
# 2 Aspect: yy, 	 route (1, 0), target speed 40.0 mph
# 3 Aspect: r, 	 route None, target speed 0.0 mph
# 4 Aspect: r, 	 route None, target speed 0.0 mph
# 5 Aspect: y, 	 route (1, 0), target speed 20.0 mph
# 6 Aspect: r, 	 route None, target speed 0.0 mph
# 7 Aspect: r, 	 route None, target speed 0.0 mph
# 8 Aspect: r, 	 route None, target speed 0.0 mph
# 9 Aspect: r, 	 route None, target speed 0.0 mph
# 10 Aspect: r, 	 route None, target speed 0.0 mph

# %%
k166.curr_brake_distance_abs/30*1610
# Out:
# 412.8484927972387

# %%
[print(b.routing) for b in sys.bigblocks]
# Out:
# ((ControlPoint0, 1), (ControlPoint3, 0))
# ((ControlPoint4, 0), (ControlPoint3, 1))
# ((ControlPoint3, 3), (ControlPoint4, 2))
# ((ControlPoint6, 0), (ControlPoint4, 1))
# None
# None
# None
# [None, None, None, None, None, None, None]

# %%
from infrastructure import Track, Block, BigBlock
from system import System
from train import Train
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta
import numpy as np
def string_diagram(sys, start_time, end_time):
    '''To draw the string diagram based on the schedule dictionary for all the trains. 
    '''
    colors = ['red','green','blue','black','orange','cyan','magenta']
    color_num = len(colors)
    x, y = [], []
    for i in range(len(sys.trains)):
        x.append([])
        y.append([])
        for j in range(len(sys.trains[i].time_pos_list)):
            x[i].append(datetime.fromtimestamp(sys.trains[i].time_pos_list[j][0]))
            y[i].append(sys.trains[i].time_pos_list[j][1])
            # x[i].append(sys.trains[i].time_pos_list[j][0])
            # y[i].append(sys.trains[i].time_pos_list[j][1])

    y = [i for _,i in sorted(zip([i[0] for i in x], y))]
    x = sorted(x, key = lambda x: x[0])
    assert len(x) == len(y)
    train_idx = list(range(len(x)))
    t_color = [colors[x.index(i)%color_num] for i in x]
    min_t, max_t = min([i[0] for i in x]), max([i[-1] for i in x])

    #plt.ion()
    plt.title('Result Analysis')
    hours = mdates.HourLocator()
    minutes = mdates.MinuteLocator()
    seconds = mdates.SecondLocator()
    dateFmt = mdates.DateFormatter("%H:%M")
    plt.gca().xaxis.set_major_locator(hours)
    plt.gca().xaxis.set_minor_locator(minutes)
    plt.gca().xaxis.set_major_formatter(dateFmt)
    plt.xticks(rotation=90)
    plt.grid(True, linestyle = "-.", color = "r", linewidth = "0.1")
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Mile Post/miles')
    start_time = int(start_time.timestamp())
    end_time = int(end_time.timestamp())
    plt.axis([(datetime.fromtimestamp(start_time - 500)), \
            (datetime.fromtimestamp(end_time + 500)), -5 , 55])
    #===============================================================================
    # time_length = end_time - start_time
    # step_size = 10
    # for start in range(1,time_length + 1, step_size):
    #     plt.axis([(datetime.fromtimestamp(start_time - 500)), \
    #         (datetime.fromtimestamp(end_time + 500)), -5 , 55])
         
    #     for n in range(len(x)-1):
    #         new_x_y = [[mdates.date2num(datetime.fromtimestamp(i)), j] for i, j in zip(x[n], y[n]) if i < start_time + start and i > start_time + start - 1 - step_size]
    #         new_x = []
    #         new_y = []
    #         for i , j in new_x_y:
    #             new_x.append(i)
    #             new_y.append(j)
    #         if(len(new_x) == 0):
    #             continue
    #         plt.plot(new_x, new_y, color=t_color[n])
    #         # print('==============')
    #         # print('Length of new_x: {}'.format(len(new_x)))
    #         # print('Length of new_y: {}'.format(len(new_y)))
    #     plt.pause(0.00001)
    #===============================================================================
    
    for n in range(len(x)):
        #assert len(x[n]) == len(y[n]) == t_color[n]
        plt.plot([mdates.date2num(i) for i in x[n]], y[n], color=t_color[n])
    plt.gca().axhspan(15,20,color='yellow',alpha=0.5)
    plt.gca().axhspan(30,35,color='yellow',alpha=0.5)
    plt.gca().axvspan((datetime.fromtimestamp(start_time + 90 * 60)),(datetime.fromtimestamp(start_time + 150 * 60)),color='black',alpha=0.5)
    plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
    plt.rcParams['figure.dpi'] = 200
    import pylab; pylab.rcParams['figure.figsize'] = (15.0, 8.0)
    plt.show()
    #plt.ioff()
string_diagram(sys, sim_init_time, sim_term_time)
# Out:
# No handles with labels found to put in legend.

# %%
((k166.curr_speed*3600)**2-k166.curr_target_spd_abs*3600**2)/7200
# Out:
# -19.415034511653136

# %%
for n in range(3600):
    print('k165: curr_MP: {}, curr_spd: {}, curr_tgt_spd'.format(k165.curr_MP, k165.curr_speed, k165.curr_target_spd_abs))
    print('k166: curr_MP: {}, curr_spd: {}, curr_tgt_spd'.format(k166.curr_MP, k166.curr_speed, k166.curr_target_spd_abs))
    k166.update_acc()
    k165.update_acc()
    sys.sys_time+=1
# Out:
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# ...
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd
# k165: curr_MP: 25.544318098647476, curr_spd: 0, curr_tgt_spd
# k166: curr_MP: 4.498811346044107, curr_spd: 0, curr_tgt_spd

# %%
v2=k166.curr_target_spd_abs
v1=k166.curr_speed
a = k166.curr_acc
(v2**2-v1**2)/(2*a)
# Out:
# -3.556605286883763

# %%
(v1**2-v2**2)/(2*a)
# Out:
# 3.556605286883763
